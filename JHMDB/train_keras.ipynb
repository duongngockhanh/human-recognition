# %%
import numpy as np
import math
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import glob
import gc
from utils import *
from tqdm import tqdm
import pickle

from keras.optimizers import *
from keras.models import Model
from keras.layers import *
from keras.layers.core import *
from keras.layers.convolutional import *
from keras import backend as K
import keras
import tensorflow as tf
from keras.models import load_model

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
random.seed(123)

class Config():
    def __init__(self):
        self.frame_l = 40 # the length of frames ################################################## Original: 32
        self.joint_n = 18 # the number of joints ################################################## Original: 15
        self.joint_d = 2 # the dimension of joints
        self.clc_num = 2 # the number of class   ################################################## Original: 21
        self.feat_d = 153                        ################################################## Original: 105
        self.filters = 16
        # self.data_dir = '/mnt/nasbi/homes/fan/projects/action/skeleton/data/JHMDB/'
C = Config()

# %%
def poses_diff(x):
    H, W = x.get_shape()[1],x.get_shape()[2]
    x = tf.subtract(x[:,1:,...],x[:,:-1,...])
    x = tf.image.resize(x,size=[H,W]) 
    return x

def pose_motion(P,frame_l):
    P_diff_slow = Lambda(lambda x: poses_diff(x))(P)
    P_diff_slow = Reshape((frame_l,-1))(P_diff_slow)
    P_fast = Lambda(lambda x: x[:,::2,...])(P)
    P_diff_fast = Lambda(lambda x: poses_diff(x))(P_fast)
    P_diff_fast = Reshape((int(frame_l/2),-1))(P_diff_fast)
    return P_diff_slow,P_diff_fast
    
def c1D(x,filters,kernel):
    x = Conv1D(filters, kernel_size=kernel,padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def block(x,filters):
    x = c1D(x,filters,3)
    x = c1D(x,filters,3)
    return x
    
def d1D(x,filters):
    x = Dense(filters,use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def build_FM(frame_l=32,joint_n=22,joint_d=2,feat_d=231,filters=16):   
    M = Input(shape=(frame_l,feat_d))
    P = Input(shape=(frame_l,joint_n,joint_d))
    
    diff_slow,diff_fast = pose_motion(P,frame_l)
    
    x = c1D(M,filters*2,1)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,3)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,1)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x_d_slow = c1D(diff_slow,filters*2,1)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,3)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,1)
    x_d_slow = MaxPool1D(2)(x_d_slow)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
        
    x_d_fast = c1D(diff_fast,filters*2,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,3) 
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,1) 
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
   
    x = concatenate([x,x_d_slow,x_d_fast])
    x = block(x,filters*2)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)
    
    x = block(x,filters*4)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*8)
    x = SpatialDropout1D(0.1)(x)
    
    return Model(inputs=[M,P],outputs=x)


def build_DD_Net(C):
    M = Input(name='M', shape=(C.frame_l,C.feat_d))  
    P = Input(name='P', shape=(C.frame_l,C.joint_n,C.joint_d)) 
    
    FM = build_FM(C.frame_l,C.joint_n,C.joint_d,C.feat_d,C.filters)
    
    x = FM([M,P])

    x = GlobalMaxPool1D()(x)
    
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = Dense(C.clc_num, activation='softmax')(x)
    
    ######################Self-supervised part
    model = Model(inputs=[M,P],outputs=x)
    return model

# %%
DD_Net = build_DD_Net(C)
DD_Net.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  M (InputLayer)                 [(None, 40, 153)]    0           []
#
#  P (InputLayer)                 [(None, 40, 18, 2)]  0           []
#
#  model (Functional)             (None, 5, 128)       114976      ['M[0][0]',
#                                                                   'P[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 128)         0           ['model[0][0]']
#  xPooling1D)
#
#  dense (Dense)                  (None, 128)          16384       ['global_max_pooling1d[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 128)         512         ['dense[0][0]']
#  ormalization)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 128)          0           ['batch_normalization_15[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['leaky_re_lu_15[0][0]']
#
#  dense_1 (Dense)                (None, 128)          16384       ['dropout[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 128)         512         ['dense_1[0][0]']
#  ormalization)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 128)          0           ['batch_normalization_16[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['leaky_re_lu_16[0][0]']
#
#  dense_2 (Dense)                (None, 2)            258         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 149,026
# Trainable params: 147,234
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %% [markdown]
# # Train

# %%
def data_generator(T,C,le):
    X_0 = []
    X_1 = []
    Y = []
    for i in tqdm(range(len(T['pose']))): 
        p = np.copy(T['pose'][i])
        p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)

        label = np.zeros(C.clc_num)
        label[le.transform(T['label'])[i]-1] = 1   

        M = get_CG(p,C)

        X_0.append(M)
        X_1.append(p)
        Y.append(label)

    X_0 = np.stack(X_0)  
    X_1 = np.stack(X_1) 
    Y = np.stack(Y)
    return X_0,X_1,Y

# %%
import os

res_folders = "a3_res_npy"

name_list = os.listdir(res_folders)

pose_list = []

for name in name_list:
    path = os.path.join(res_folders, name)
    temp_array = np.load(path)
    pose_list.append(temp_array)

label_list = ["sleep"] * len(pose_list)

Train = {"pose": pose_list, "label": label_list}

for i in range(len(label_list)):
    temp = np.random.rand(40, 18, 2)
    Train["pose"].append(temp)
    Train["label"].append("nosleep")

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(Train['label'])

X_0,X_1,Y = data_generator(Train,C,le)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 198.13it/s]

# %%
lr = 1e-3
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=1e-5)
history = DD_Net.fit([X_0,X_1],Y,
                    batch_size=len(Y),
                    epochs=200,
                    verbose=True,
                    shuffle=True,
                    callbacks=[lrScheduler]   
                    )
# Out:
# Epoch 1/200
# 1/1 [==============================] - 3s 3s/step - loss: 1.1323 - accuracy: 0.5000 - lr: 0.0010
# Epoch 2/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.8944 - accuracy: 0.5625 - lr: 0.0010
# Epoch 3/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5823 - accuracy: 0.6875 - lr: 0.0010
# Epoch 4/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5846 - accuracy: 0.6875 - lr: 0.0010
# Epoch 5/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4772 - accuracy: 0.7500 - lr: 0.0010
# Epoch 6/200
# 1/1 [==============================] - 0s 71ms/step - loss: 0.5016 - accuracy: 0.7500 - lr: 0.0010
# Epoch 7/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3417 - accuracy: 0.8125 - lr: 0.0010
# Epoch 8/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4438 - accuracy: 0.7500 - lr: 0.0010
# Epoch 9/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4097 - accuracy: 0.8125 - lr: 0.0010
# Epoch 10/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2843 - accuracy: 0.9375 - lr: 0.0010
# Epoch 11/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3550 - accuracy: 0.8750 - lr: 0.0010
# Epoch 12/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2585 - accuracy: 0.8750 - lr: 0.0010
# Epoch 13/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2612 - accuracy: 0.8125 - lr: 0.0010
# Epoch 14/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2182 - accuracy: 0.8750 - lr: 0.0010
# Epoch 15/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1456 - accuracy: 0.9375 - lr: 0.0010
# Epoch 16/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1724 - accuracy: 0.8750 - lr: 0.0010
# Epoch 17/200
# 1/1 [==============================] - 0s 84ms/step - loss: 0.4175 - accuracy: 0.9375 - lr: 0.0010
# Epoch 18/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3709 - accuracy: 0.8125 - lr: 0.0010
# Epoch 19/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1867 - accuracy: 0.9375 - lr: 0.0010
# Epoch 20/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3986 - accuracy: 0.8750 - lr: 0.0010
# Epoch 21/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0497 - accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 22/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2191 - accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 23/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0683 - accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 24/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2294 - accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 25/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1100 - accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 26/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1022 - accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 27/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0704 - accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 28/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0424 - accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 29/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2115 - accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 30/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0607 - accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 31/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0859 - accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 32/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1552 - accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 33/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0826 - accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 34/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1166 - accuracy: 0.9375 - lr: 2.5000e-04
# Epoch 35/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0736 - accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 36/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0787 - accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 37/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0399 - accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 38/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0881 - accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 39/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0263 - accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 40/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0520 - accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 41/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0604 - accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 42/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0493 - accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 43/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0422 - accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 44/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0463 - accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 45/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1013 - accuracy: 0.9375 - lr: 1.2500e-04
# Epoch 46/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0751 - accuracy: 0.9375 - lr: 1.2500e-04
# Epoch 47/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0540 - accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 48/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1000 - accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 49/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0281 - accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 50/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0142 - accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 51/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0710 - accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 52/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0678 - accuracy: 0.9375 - lr: 1.2500e-04
# Epoch 53/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1030 - accuracy: 0.9375 - lr: 1.2500e-04
# Epoch 54/200
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0787 - accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 55/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0354 - accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 56/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0599 - accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 57/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0324 - accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 58/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0240 - accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 59/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1322 - accuracy: 0.9375 - lr: 6.2500e-05
# Epoch 60/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0367 - accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 61/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0688 - accuracy: 0.9375 - lr: 6.2500e-05
# Epoch 62/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0466 - accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 63/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0203 - accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 64/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0235 - accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 65/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0234 - accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 66/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0657 - accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 67/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0378 - accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 68/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0210 - accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 69/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0448 - accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 70/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0388 - accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 71/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0666 - accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 72/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0398 - accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 73/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0804 - accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 74/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0400 - accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 75/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0649 - accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 76/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0185 - accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 77/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0674 - accuracy: 0.9375 - lr: 1.5625e-05
# Epoch 78/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0401 - accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 79/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0984 - accuracy: 0.9375 - lr: 1.5625e-05
# Epoch 80/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0837 - accuracy: 0.9375 - lr: 1.5625e-05
# Epoch 81/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0271 - accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 82/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0341 - accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 83/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0643 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 84/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1201 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 85/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0205 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 86/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0519 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 87/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0350 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 88/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0182 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 89/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0503 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 90/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0410 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 91/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0208 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 92/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0446 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 93/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0398 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 94/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0227 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 95/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0799 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 96/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0722 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 97/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0256 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 98/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0299 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 99/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0197 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 100/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0619 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 101/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0270 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 102/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0218 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 103/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0614 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 104/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0103 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 105/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1809 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 106/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0770 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 107/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0356 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 108/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0314 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 109/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0292 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 110/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2078 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 111/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0625 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 112/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0880 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 113/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0582 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 114/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0306 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 115/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0597 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 116/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0374 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 117/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0737 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 118/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0374 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 119/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0301 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 120/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0153 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 121/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0894 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 122/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0366 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 123/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0465 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 124/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0314 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 125/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1033 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 126/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0214 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 127/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0759 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 128/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0431 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 129/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0596 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 130/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0154 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 131/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0934 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 132/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0280 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 133/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0486 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 134/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0249 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 135/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0287 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 136/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0418 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 137/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0397 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 138/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0683 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 139/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0289 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 140/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0387 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 141/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0253 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 142/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0361 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 143/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0561 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 144/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0635 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 145/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1586 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 146/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0496 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 147/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0250 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 148/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0174 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 149/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0491 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 150/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0303 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 151/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0699 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 152/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0571 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 153/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0426 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 154/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0399 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 155/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0456 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 156/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0189 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 157/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0314 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 158/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0890 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 159/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0354 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 160/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0960 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 161/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0238 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 162/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0213 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 163/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0251 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 164/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0337 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 165/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0654 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 166/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0274 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 167/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0348 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 168/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0311 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 169/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0269 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 170/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0255 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 171/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0564 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 172/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0827 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 173/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0207 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 174/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0131 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 175/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0698 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 176/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3254 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 177/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0526 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 178/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0266 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 179/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0375 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 180/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0624 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 181/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0181 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 182/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0326 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 183/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0586 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 184/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0196 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 185/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0636 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 186/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0481 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 187/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0218 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 188/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0373 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 189/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0948 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 190/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0246 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 191/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0181 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 192/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1176 - accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 193/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0372 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 194/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0202 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 195/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0207 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 196/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0412 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 197/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0141 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 198/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0772 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 199/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0152 - accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 200/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0594 - accuracy: 1.0000 - lr: 1.0000e-05

# %%
DD_Net.save('weights/model.h5')

# %% [markdown]
# # Inference

# %%
# Run this cell if the weight file is available
path_weight = "weights/model.h5"
DD_Net_1 = build_DD_Net(C)
DD_Net_1 = load_model(path_weight)

# %%
# path_keypoints = "video_keypoints.npy"
# p = np.load(path_keypoints)

p = Train["pose"][0]
# p = np.random.randn(40, 18, 2)

p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)
M = get_CG(p,C)

res1 = DD_Net_1.predict([np.array([M]), np.array([p])])
print("Action:", np.argmax(res1[0]))
# Out:
# 1/1 [==============================] - 0s 436ms/step
# Action: 0

# %%
print(p.shape)
# Out:
# (40, 18, 2)

# %% [markdown]
# # Convert to Onnx

# %%
import tensorflow as tf
import tf2onnx
import onnx

input_signature = [tf.TensorSpec([None, 40, 153], tf.float32, name='x'), tf.TensorSpec([None, 40, 18, 2], tf.float32, name='y')]
# Use from_function for tf functions
onnx_model, _ = tf2onnx.convert.from_keras(DD_Net_1, input_signature, opset=13)
onnx.save(onnx_model, "weights/model.onnx")
# Out:
# 2023-11-22 17:52:06.445559: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-11-22 17:52:06.445645: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-11-22 17:52:06.799402: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-11-22 17:52:06.799497: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
